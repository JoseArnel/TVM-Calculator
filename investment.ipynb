# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('investment.csv')
plt.plot(data.Balance / 10**6)
plt.plot(data.Principal / 10**6)
plt.plot(data.Interest / 10**6)
plt.
plt.legend(['Balance', 'Interest', 'Principal'])
plt.xlabel("Year")
plt.ylabel("$(Millions)")
plt.show()

# %%
data
# Out:
#     Year  Balance  Principal  Interest
# 0      1    59500      50000     50000
# 1      2    69665      56000     59500
# 2      3    80542      62000     69665
# 3      4    92179      68000     80542
# 4      5   104632      74000     92179
# 5      6   117956      80000    104632
# 6      7   132213      86000    117956
# 7      8   147468      92000    132213
# 8      9   163791      98000    147468
# 9     10   181256     104000    163791
# 10    11   199944     110000    181256
# 11    12   219940     116000    199944
# 12    13   241336     122000    219940
# 13    14   264230     128000    241336
# 14    15   288726     134000    264230
# 15    16   314937     140000    288726
# 16    17   342982     146000    314937
# 17    18   372991     152000    342982
# 18    19   405100     158000    372991
# 19    20   439457     164000    405100
# 20    21   476219     170000    439457
# 21    22   515555     176000    476219
# 22    23   557643     182000    515555
# 23    24   602678     188000    557643
# 24    25   650866     194000    602678
# 25    26   702426     200000    650866
# 26    27   757596     206000    702426
# 27    28   816628     212000    757596
# 28    29   879792     218000    816628
# 29    30   947377     224000    879792
# 30    31  1019694     230000    947377
